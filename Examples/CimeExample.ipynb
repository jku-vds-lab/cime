# %% [markdown]
# First we need to import the packages and functions needed for this analysis

# %%
#####################################
### import the used functions
#####################################
#for umap you need the umap-learn package
import umap.umap_ as umap
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs, Descriptors
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import PandasTools
import pandas as pd
import catboost
import shap
import numpy as np

# %% [markdown]
# After this we will define several functions needed for our analysis.

# %%
#######################################
###define the used functions
#######################################

#define a function that trnasforms smiles RDKit Mol objects
def smiles_to_mols(smis):
    """Convert a list of smiles to a list of RDKit Mol objects"""
    if not isinstance(smis, list):
        raise TypeError("Please provide smiles as a list")
    mols = []
    successful_inds = []
    for ind, smi in enumerate(smis):
        # RDKit will sometimes 'fail' but instead of throwing an
        # error it will (sometimes!) print a warning and return None.
        m = Chem.MolFromSmiles(smi, sanitize=True)
        if m is None:
            print("Mol generation failed for", smi, "(index", ind, ")\n")
        else:
            mols.append(m)
            successful_inds.append(ind)
    return mols, successful_inds


# define a function to calculate count based morgan fingerprints
def calc_morgan_counts_for_smiles(mol, radius=2, nBits=2048):
    try:
        fpCounts = AllChem.GetHashedMorganFingerprint(
            mol, radius, nBits=nBits, includeRedundantEnvironments=False)
        array = np.zeros((0,), dtype=np.int8)
        DataStructs.ConvertToNumpyArray(fpCounts, array)
    except:
        print("Failure in calc_morgan_counts_for_smiles()")
        array = np.repeat(np.nan, nBits)

    return array


#get the substructure indices for a specfied radius around an atomID
def getSubstructIndex(mol,atomID,radius):
    if radius>0:
        env = Chem.FindAtomEnvironmentOfRadiusN(mol,radius,atomID)
        atomsToUse=[]
        for b in env:
            atomsToUse.append(mol.GetBondWithIdx(b).GetBeginAtomIdx())
            atomsToUse.append(mol.GetBondWithIdx(b).GetEndAtomIdx())
        atomsToUse = list(set(atomsToUse))
    else:
        atomsToUse = [atomID]
        env=None
    return(atomsToUse)

#get the substructure indices for each fingerprint bit
def calc_indices_for_fingerprints(smiles,radius = 2,nBits=2048):
   mol = Chem.MolFromSmiles(smiles,sanitize = True)
   bi = {}
   fp = AllChem.GetHashedMorganFingerprint(mol,radius = radius, nBits=nBits, includeRedundantEnvironments=False,bitInfo=bi)
   fp = fp.GetNonzeroElements()
   #weights = [0  for i in mol.GetAtoms()]
   #weights[slice(mol.GetSubstructMatch(Chem.MolFromSmiles('CNC(=O)C(C)(C)C',sanitize = True)))] += 1


   fp_indices = {}
   for fragment_id, count in fp.items():
      sub_indices = []
      for i in range(count):
         #print(i)
         root, radius = bi[fragment_id][i]
         subindex = getSubstructIndex(mol,root,radius)
         sub_indices = sub_indices + subindex

      sub_indices = list(set(sub_indices))

      fp_indices[fragment_id] = sub_indices
   fp_indices = {"fp_morgan_counts_" +  str(k): v for k, v in fp_indices.items() }

   return(fp_indices)

#we also need a function that calculates the attribution of each atom to the final 
#prediction, for direction you can choose between "up": all positive attributions
#"down": all negative attributions and recommended "both": summing up over all attributions
def atom_attributions(mol, indices, shap_vals, featureNames, direction="both"):
    """
    Sum up the attributions to the model predictions (Shap values) for each atom in mol.

    Parameters:
        mol: rdkit molecule object
        indices (dict): a dictionary with keys = feature names and values = list of atom positions in mol (output of calc_indices_for_fingerprints())
        shap_vals: a numpy array of dimensions (len(featureNames))
        featureNames (np.array): numpy array containing the feature names for shap_vals
        direction (str): whether to consider positive (up), negative (down) or both shap_vals contributions

    Returns:
        np.array: each element = 1 atom of mol and the values are the summed contributions from shap_vals
    """
    ## TO DO: add support for MACCS keys

    # get for each fingerprint bit the atom numbers mapping to that bit and initialise weights to 0
    curWeights = np.array([0 for i in range(mol.GetNumAtoms())], 'float64')

    # step through each index (dictionary)
    for j in indices:
        # retrieve index to subset into the featureNames and the corresponding shap values array
        curFPIndex = [i for i, s in enumerate(featureNames) if s == j]
        if len(curFPIndex) == 0:
            continue
        if len(curFPIndex) > 1:
            raise IndexError("Found several matches for feature " + j)
        # do something only if (i) the fingerprint bit was in the selected features
        # and (ii) only if the retrieved shap value is positive/negative (direction argument)
        if (direction == "up" and shap_vals[curFPIndex[0]] > 0) or (direction == "down" and shap_vals[curFPIndex[0]] < 0) or (direction == "both"):
            # use the atom numbers ('positions') to update the curWeights array, where
            # each atom of the current molecule is represented
            # one atom may be part of several fingerprints so the summing has to be done across
            # all fingerprints
            for pos in indices[j]:
                #value = (curWeights[pos] + shap_vals[curFPIndex[0]])
                value = (curWeights[pos] + (shap_vals[curFPIndex[0]]/len(indices[j])))
                curWeights[pos] = value

    return curWeights

# %% [markdown]
# To test the code we define some smiles, this is just a proof of concept, please feel free to add smiles of your own to get abigger dataset.

# %%
#######################################################
##define some smiles
#######################################################

smiles = ["c1cccc[nH+]1",
      "C[N+](C)(C)C","c1ccccc1[NH3+]",
      "CC(=O)[O-]","c1ccccc1[O-]",
      "CCS",
      "C[N-]S(=O)(=O)C",
      "C[N-]C=C","C[N-]N=C",
      "c1ccc[n-]1",
      "CC[N-]C(=O)CC"]

# %% [markdown]
# Before we can use the smiles some preprocessing steps have to be performed to make them canonical and also to store them as mols for use in Rdkit

# %%
################################################################################
##make sure that the smiles are canonical to have full compatibility with CIME
################################################################################

#canonicalize smiles
mols, successful_inds = smiles_to_mols(smiles)
# get canonical smiles
smiles = [Chem.MolToSmiles(m) for m in mols]

#generate some names for the smiles
smiles_names = [i for i in range(len(smiles))]

# %% [markdown]
# Before we continue we store the smiles also as a data frame

# %%
##################################################
# put the smiles and info into a data frame
###################################################
sdfExportData = pd.DataFrame({'names': smiles_names,
        'smiles': smiles})

# %% [markdown]
# Now that we did that we can calculate the logp

# %%
################################################################################
##calculate the logp for each of them
################################################################################

logp = [Descriptors.MolLogP(i) for i in mols]

# %% [markdown]
# The basis for our model are count based morgan fingerprints which we calculate and store in a matrix format

# %%
##############################################
##calculate the morgan fingerprints
################################################################################

# calculate the morgan counts fingerprints
featuresMorganCounts = [calc_morgan_counts_for_smiles(
    mol, radius=2, nBits=2048) for mol in mols]
columns = ["fp_morgan_counts_" + str(i) for i in range(2048)]
featuresMorganCounts = pd.DataFrame(featuresMorganCounts, columns=[
                                  "fp_morgan_counts_" + str(i) for i in range(2048)])

# %% [markdown]
# Now we can train the model

# %%
##################################################
##train a model on the values
##################################################

model = catboost.CatBoostRegressor()
# Fit model
model.fit(featuresMorganCounts, logp)
# Out:
# Learning rate set to 0.020078
# 0:	learn: 0.6529934	total: 140ms	remaining: 2m 19s
# 1:	learn: 0.6501014	total: 141ms	remaining: 1m 10s
# 2:	learn: 0.6468481	total: 141ms	remaining: 47s
# 3:	learn: 0.6441279	total: 142ms	remaining: 35.3s
# 4:	learn: 0.6414791	total: 143ms	remaining: 28.4s
# 5:	learn: 0.6383103	total: 143ms	remaining: 23.7s
# 6:	learn: 0.6355829	total: 144ms	remaining: 20.4s
# 7:	learn: 0.6318449	total: 145ms	remaining: 17.9s
# 8:	learn: 0.6284757	total: 145ms	remaining: 16s
# 9:	learn: 0.6257633	total: 146ms	remaining: 14.4s
# 10:	learn: 0.6229713	total: 146ms	remaining: 13.2s
# 11:	learn: 0.6196277	total: 147ms	remaining: 12.1s
# 12:	learn: 0.6170333	total: 147ms	remaining: 11.2s
# 13:	learn: 0.6137229	total: 148ms	remaining: 10.4s
# 14:	learn: 0.6111082	total: 148ms	remaining: 9.74s
# 15:	learn: 0.6081114	total: 149ms	remaining: 9.15s
# 16:	learn: 0.6054127	total: 149ms	remaining: 8.64s
# 17:	learn: 0.6024950	total: 150ms	remaining: 8.18s
# 18:	learn: 0.5998816	total: 150ms	remaining: 7.76s
# 19:	learn: 0.5974411	total: 151ms	remaining: 7.38s
# 20:	learn: 0.5948571	total: 151ms	remaining: 7.04s
# 21:	learn: 0.5919822	total: 152ms	remaining: 6.73s
# 22:	learn: 0.5884381	total: 152ms	remaining: 6.46s
# 23:	learn: 0.5860311	total: 152ms	remaining: 6.19s
# 24:	learn: 0.5836742	total: 153ms	remaining: 5.96s
# 25:	learn: 0.5810578	total: 153ms	remaining: 5.75s
# 26:	learn: 0.5782653	total: 154ms	remaining: 5.55s
# 27:	learn: 0.5754984	total: 155ms	remaining: 5.37s
# 28:	learn: 0.5727307	total: 155ms	remaining: 5.19s
# 29:	learn: 0.5698933	total: 156ms	remaining: 5.03s
# 30:	learn: 0.5677174	total: 156ms	remaining: 4.88s
# 31:	learn: 0.5649782	total: 157ms	remaining: 4.74s
# 32:	learn: 0.5627036	total: 157ms	remaining: 4.6s
# 33:	learn: 0.5604548	total: 157ms	remaining: 4.47s
# 34:	learn: 0.5578328	total: 158ms	remaining: 4.36s
# 35:	learn: 0.5556106	total: 159ms	remaining: 4.25s
# 36:	learn: 0.5531828	total: 159ms	remaining: 4.15s
# 37:	learn: 0.5502346	total: 160ms	remaining: 4.05s
# 38:	learn: 0.5474375	total: 161ms	remaining: 3.96s
# 39:	learn: 0.5449863	total: 161ms	remaining: 3.87s
# 40:	learn: 0.5427804	total: 162ms	remaining: 3.78s
# 41:	learn: 0.5399984	total: 162ms	remaining: 3.69s
# 42:	learn: 0.5376278	total: 163ms	remaining: 3.62s
# 43:	learn: 0.5353788	total: 163ms	remaining: 3.54s
# 44:	learn: 0.5333483	total: 164ms	remaining: 3.47s
# 45:	learn: 0.5308566	total: 164ms	remaining: 3.41s
# 46:	learn: 0.5278007	total: 165ms	remaining: 3.34s
# 47:	learn: 0.5256878	total: 165ms	remaining: 3.27s
# 48:	learn: 0.5228558	total: 165ms	remaining: 3.21s
# 49:	learn: 0.5205787	total: 166ms	remaining: 3.16s
# 50:	learn: 0.5186624	total: 167ms	remaining: 3.1s
# 51:	learn: 0.5166402	total: 167ms	remaining: 3.05s
# 52:	learn: 0.5141465	total: 168ms	remaining: 3s
# 53:	learn: 0.5116924	total: 169ms	remaining: 2.96s
# 54:	learn: 0.5090220	total: 170ms	remaining: 2.92s
# 55:	learn: 0.5069732	total: 171ms	remaining: 2.88s
# 56:	learn: 0.5050213	total: 171ms	remaining: 2.83s
# 57:	learn: 0.5028863	total: 171ms	remaining: 2.79s
# 58:	learn: 0.5001513	total: 172ms	remaining: 2.75s
# 59:	learn: 0.4979592	total: 173ms	remaining: 2.7s
# 60:	learn: 0.4956096	total: 173ms	remaining: 2.66s
# 61:	learn: 0.4932515	total: 174ms	remaining: 2.63s
# 62:	learn: 0.4912860	total: 174ms	remaining: 2.59s
# 63:	learn: 0.4891070	total: 175ms	remaining: 2.55s
# 64:	learn: 0.4867674	total: 175ms	remaining: 2.52s
# 65:	learn: 0.4842476	total: 176ms	remaining: 2.49s
# 66:	learn: 0.4817336	total: 176ms	remaining: 2.45s
# 67:	learn: 0.4799576	total: 177ms	remaining: 2.42s
# 68:	learn: 0.4773786	total: 177ms	remaining: 2.39s
# 69:	learn: 0.4748531	total: 178ms	remaining: 2.36s
# 70:	learn: 0.4726050	total: 178ms	remaining: 2.33s
# 71:	learn: 0.4704388	total: 179ms	remaining: 2.3s
# 72:	learn: 0.4685530	total: 179ms	remaining: 2.28s
# 73:	learn: 0.4663395	total: 180ms	remaining: 2.25s
# 74:	learn: 0.4643817	total: 180ms	remaining: 2.23s
# 75:	learn: 0.4622157	total: 181ms	remaining: 2.2s
# 76:	learn: 0.4605956	total: 181ms	remaining: 2.17s
# 77:	learn: 0.4583075	total: 182ms	remaining: 2.15s
# 78:	learn: 0.4557590	total: 183ms	remaining: 2.13s
# 79:	learn: 0.4540486	total: 183ms	remaining: 2.11s
# 80:	learn: 0.4524461	total: 183ms	remaining: 2.08s
# 81:	learn: 0.4503276	total: 184ms	remaining: 2.06s
# 82:	learn: 0.4481365	total: 184ms	remaining: 2.04s
# 83:	learn: 0.4460221	total: 185ms	remaining: 2.02s
# 84:	learn: 0.4439559	total: 185ms	remaining: 1.99s
# 85:	learn: 0.4423017	total: 186ms	remaining: 1.97s
# 86:	learn: 0.4406586	total: 186ms	remaining: 1.95s
# 87:	learn: 0.4391412	total: 186ms	remaining: 1.93s
# 88:	learn: 0.4370631	total: 187ms	remaining: 1.91s
# 89:	learn: 0.4354345	total: 187ms	remaining: 1.89s
# 90:	learn: 0.4338327	total: 187ms	remaining: 1.87s
# 91:	learn: 0.4321384	total: 188ms	remaining: 1.85s
# 92:	learn: 0.4300587	total: 189ms	remaining: 1.84s
# 93:	learn: 0.4277400	total: 189ms	remaining: 1.82s
# 94:	learn: 0.4259640	total: 190ms	remaining: 1.8s
# 95:	learn: 0.4240021	total: 190ms	remaining: 1.79s
# 96:	learn: 0.4224572	total: 191ms	remaining: 1.77s
# 97:	learn: 0.4207998	total: 191ms	remaining: 1.76s
# 98:	learn: 0.4186274	total: 191ms	remaining: 1.74s
# 99:	learn: 0.4164557	total: 192ms	remaining: 1.73s
# 100:	learn: 0.4144643	total: 193ms	remaining: 1.71s
# 101:	learn: 0.4125453	total: 193ms	remaining: 1.7s
# 102:	learn: 0.4103794	total: 194ms	remaining: 1.69s
# 103:	learn: 0.4084729	total: 194ms	remaining: 1.67s
# 104:	learn: 0.4066244	total: 195ms	remaining: 1.66s
# 105:	learn: 0.4046540	total: 195ms	remaining: 1.65s
# 106:	learn: 0.4033552	total: 196ms	remaining: 1.63s
# 107:	learn: 0.4013387	total: 196ms	remaining: 1.62s
# 108:	learn: 0.3995518	total: 196ms	remaining: 1.6s
# 109:	learn: 0.3981071	total: 197ms	remaining: 1.59s
# 110:	learn: 0.3966859	total: 197ms	remaining: 1.58s
# 111:	learn: 0.3952767	total: 197ms	remaining: 1.56s
# 112:	learn: 0.3933474	total: 198ms	remaining: 1.55s
# 113:	learn: 0.3915859	total: 198ms	remaining: 1.54s
# 114:	learn: 0.3899760	total: 199ms	remaining: 1.53s
# 115:	learn: 0.3875476	total: 199ms	remaining: 1.52s
# 116:	learn: 0.3862123	total: 200ms	remaining: 1.51s
# 117:	learn: 0.3844776	total: 200ms	remaining: 1.5s
# 118:	learn: 0.3826342	total: 201ms	remaining: 1.49s
# 119:	learn: 0.3808506	total: 201ms	remaining: 1.48s
# 120:	learn: 0.3795079	total: 202ms	remaining: 1.46s
# 121:	learn: 0.3782611	total: 202ms	remaining: 1.45s
# 122:	learn: 0.3765296	total: 202ms	remaining: 1.44s
# 123:	learn: 0.3745037	total: 203ms	remaining: 1.43s
# 124:	learn: 0.3732291	total: 203ms	remaining: 1.42s
# 125:	learn: 0.3714237	total: 204ms	remaining: 1.41s
# 126:	learn: 0.3696288	total: 204ms	remaining: 1.41s
# 127:	learn: 0.3683332	total: 205ms	remaining: 1.4s
# 128:	learn: 0.3667346	total: 205ms	remaining: 1.39s
# 129:	learn: 0.3649583	total: 206ms	remaining: 1.38s
# 130:	learn: 0.3632806	total: 206ms	remaining: 1.37s
# 131:	learn: 0.3620565	total: 207ms	remaining: 1.36s
# 132:	learn: 0.3608034	total: 207ms	remaining: 1.35s
# 133:	learn: 0.3593360	total: 207ms	remaining: 1.34s
# 134:	learn: 0.3573923	total: 208ms	remaining: 1.33s
# 135:	learn: 0.3558775	total: 208ms	remaining: 1.32s
# 136:	learn: 0.3541507	total: 209ms	remaining: 1.31s
# 137:	learn: 0.3525434	total: 209ms	remaining: 1.31s
# 138:	learn: 0.3511986	total: 210ms	remaining: 1.3s
# 139:	learn: 0.3494718	total: 210ms	remaining: 1.29s
# 140:	learn: 0.3478659	total: 211ms	remaining: 1.28s
# 141:	learn: 0.3462300	total: 211ms	remaining: 1.28s
# 142:	learn: 0.3447165	total: 212ms	remaining: 1.27s
# 143:	learn: 0.3432431	total: 212ms	remaining: 1.26s
# 144:	learn: 0.3416159	total: 213ms	remaining: 1.25s
# 145:	learn: 0.3397617	total: 213ms	remaining: 1.25s
# 146:	learn: 0.3383203	total: 214ms	remaining: 1.24s
# 147:	learn: 0.3368776	total: 214ms	remaining: 1.23s
# 148:	learn: 0.3356020	total: 215ms	remaining: 1.23s
# 149:	learn: 0.3341204	total: 215ms	remaining: 1.22s
# 150:	learn: 0.3326136	total: 216ms	remaining: 1.21s
# 151:	learn: 0.3311141	total: 216ms	remaining: 1.21s
# 152:	learn: 0.3299911	total: 217ms	remaining: 1.2s
# 153:	learn: 0.3285731	total: 217ms	remaining: 1.19s
# 154:	learn: 0.3272469	total: 217ms	remaining: 1.19s
# 155:	learn: 0.3257765	total: 218ms	remaining: 1.18s
# 156:	learn: 0.3242298	total: 219ms	remaining: 1.17s
# 157:	learn: 0.3227751	total: 219ms	remaining: 1.17s
# 158:	learn: 0.3212202	total: 220ms	remaining: 1.16s
# 159:	learn: 0.3198153	total: 220ms	remaining: 1.16s
# 160:	learn: 0.3183839	total: 221ms	remaining: 1.15s
# 161:	learn: 0.3172210	total: 221ms	remaining: 1.14s
# 162:	learn: 0.3161659	total: 222ms	remaining: 1.14s
# 163:	learn: 0.3146476	total: 222ms	remaining: 1.13s
# 164:	learn: 0.3132040	total: 223ms	remaining: 1.13s
# 165:	learn: 0.3116808	total: 223ms	remaining: 1.12s
# 166:	learn: 0.3102916	total: 224ms	remaining: 1.11s
# 167:	learn: 0.3090275	total: 224ms	remaining: 1.11s
# 168:	learn: 0.3075626	total: 225ms	remaining: 1.1s
# 169:	learn: 0.3061786	total: 225ms	remaining: 1.1s
# 170:	learn: 0.3046770	total: 226ms	remaining: 1.09s
# 171:	learn: 0.3034452	total: 226ms	remaining: 1.09s
# 172:	learn: 0.3020608	total: 227ms	remaining: 1.08s
# 173:	learn: 0.3007864	total: 227ms	remaining: 1.08s
# 174:	learn: 0.2994469	total: 228ms	remaining: 1.07s
# 175:	learn: 0.2984670	total: 228ms	remaining: 1.07s
# 176:	learn: 0.2970344	total: 229ms	remaining: 1.06s
# 177:	learn: 0.2955766	total: 229ms	remaining: 1.06s
# 178:	learn: 0.2943208	total: 230ms	remaining: 1.05s
# 179:	learn: 0.2927308	total: 231ms	remaining: 1.05s
# 180:	learn: 0.2913516	total: 231ms	remaining: 1.05s
# 181:	learn: 0.2900654	total: 232ms	remaining: 1.04s
# 182:	learn: 0.2886798	total: 232ms	remaining: 1.04s
# 183:	learn: 0.2871546	total: 233ms	remaining: 1.03s
# 184:	learn: 0.2858634	total: 233ms	remaining: 1.03s
# 185:	learn: 0.2847386	total: 234ms	remaining: 1.02s
# 186:	learn: 0.2836213	total: 234ms	remaining: 1.02s
# 187:	learn: 0.2824287	total: 235ms	remaining: 1.01s
# 188:	learn: 0.2810536	total: 235ms	remaining: 1.01s
# 189:	learn: 0.2797246	total: 236ms	remaining: 1s
# 190:	learn: 0.2783861	total: 236ms	remaining: 1s
# 191:	learn: 0.2771397	total: 237ms	remaining: 997ms
# 192:	learn: 0.2757595	total: 237ms	remaining: 993ms
# 193:	learn: 0.2745325	total: 238ms	remaining: 989ms
# 194:	learn: 0.2733314	total: 238ms	remaining: 984ms
# 195:	learn: 0.2721312	total: 239ms	remaining: 980ms
# 196:	learn: 0.2708380	total: 240ms	remaining: 977ms
# 197:	learn: 0.2696570	total: 240ms	remaining: 972ms
# 198:	learn: 0.2684529	total: 240ms	remaining: 968ms
# 199:	learn: 0.2671718	total: 241ms	remaining: 964ms
# 200:	learn: 0.2657608	total: 242ms	remaining: 961ms
# 201:	learn: 0.2645971	total: 242ms	remaining: 957ms
# 202:	learn: 0.2633133	total: 243ms	remaining: 953ms
# 203:	learn: 0.2619528	total: 243ms	remaining: 950ms
# 204:	learn: 0.2606767	total: 244ms	remaining: 946ms
# 205:	learn: 0.2594074	total: 245ms	remaining: 942ms
# 206:	learn: 0.2581931	total: 245ms	remaining: 939ms
# 207:	learn: 0.2570317	total: 246ms	remaining: 935ms
# 208:	learn: 0.2559170	total: 246ms	remaining: 931ms
# 209:	learn: 0.2546934	total: 247ms	remaining: 928ms
# 210:	learn: 0.2534398	total: 247ms	remaining: 925ms
# 211:	learn: 0.2523432	total: 248ms	remaining: 921ms
# 212:	learn: 0.2511116	total: 248ms	remaining: 917ms
# 213:	learn: 0.2499270	total: 249ms	remaining: 914ms
# 214:	learn: 0.2488483	total: 249ms	remaining: 910ms
# 215:	learn: 0.2477758	total: 250ms	remaining: 906ms
# 216:	learn: 0.2465753	total: 250ms	remaining: 903ms
# 217:	learn: 0.2453790	total: 251ms	remaining: 900ms
# 218:	learn: 0.2442350	total: 251ms	remaining: 897ms
# 219:	learn: 0.2430561	total: 252ms	remaining: 893ms
# 220:	learn: 0.2418781	total: 253ms	remaining: 890ms
# 221:	learn: 0.2407521	total: 253ms	remaining: 887ms
# 222:	learn: 0.2395860	total: 254ms	remaining: 883ms
# 223:	learn: 0.2384736	total: 254ms	remaining: 880ms
# 224:	learn: 0.2373689	total: 255ms	remaining: 877ms
# 225:	learn: 0.2362115	total: 255ms	remaining: 874ms
# 226:	learn: 0.2351975	total: 256ms	remaining: 871ms
# 227:	learn: 0.2340800	total: 256ms	remaining: 868ms
# 228:	learn: 0.2328849	total: 257ms	remaining: 865ms
# 229:	learn: 0.2317650	total: 257ms	remaining: 862ms
# 230:	learn: 0.2306405	total: 258ms	remaining: 859ms
# 231:	learn: 0.2295105	total: 258ms	remaining: 856ms
# 232:	learn: 0.2284467	total: 259ms	remaining: 852ms
# 233:	learn: 0.2273673	total: 260ms	remaining: 850ms
# 234:	learn: 0.2263166	total: 260ms	remaining: 847ms
# 235:	learn: 0.2253524	total: 261ms	remaining: 843ms
# 236:	learn: 0.2243115	total: 261ms	remaining: 841ms
# 237:	learn: 0.2233255	total: 262ms	remaining: 838ms
# 238:	learn: 0.2222491	total: 262ms	remaining: 835ms
# 239:	learn: 0.2211784	total: 263ms	remaining: 832ms
# 240:	learn: 0.2201150	total: 263ms	remaining: 829ms
# 241:	learn: 0.2190460	total: 264ms	remaining: 827ms
# 242:	learn: 0.2179876	total: 264ms	remaining: 824ms
# 243:	learn: 0.2169052	total: 265ms	remaining: 821ms
# 244:	learn: 0.2158974	total: 265ms	remaining: 818ms
# 245:	learn: 0.2148554	total: 266ms	remaining: 815ms
# 246:	learn: 0.2138285	total: 267ms	remaining: 812ms
# 247:	learn: 0.2128071	total: 267ms	remaining: 810ms
# 248:	learn: 0.2117910	total: 268ms	remaining: 807ms
# 249:	learn: 0.2108962	total: 268ms	remaining: 804ms
# 250:	learn: 0.2097966	total: 269ms	remaining: 802ms
# 251:	learn: 0.2088324	total: 269ms	remaining: 799ms
# 252:	learn: 0.2078373	total: 270ms	remaining: 796ms
# 253:	learn: 0.2068474	total: 270ms	remaining: 793ms
# 254:	learn: 0.2058987	total: 271ms	remaining: 791ms
# 255:	learn: 0.2049192	total: 271ms	remaining: 788ms
# 256:	learn: 0.2039016	total: 272ms	remaining: 786ms
# 257:	learn: 0.2029320	total: 272ms	remaining: 783ms
# 258:	learn: 0.2020064	total: 273ms	remaining: 781ms
# 259:	learn: 0.2010039	total: 273ms	remaining: 778ms
# 260:	learn: 0.2000854	total: 274ms	remaining: 776ms
# 261:	learn: 0.1990666	total: 274ms	remaining: 772ms
# 262:	learn: 0.1981566	total: 275ms	remaining: 770ms
# 263:	learn: 0.1972173	total: 275ms	remaining: 768ms
# 264:	learn: 0.1962330	total: 276ms	remaining: 765ms
# 265:	learn: 0.1953030	total: 277ms	remaining: 763ms
# 266:	learn: 0.1942543	total: 277ms	remaining: 761ms
# 267:	learn: 0.1932908	total: 278ms	remaining: 758ms
# 268:	learn: 0.1923758	total: 278ms	remaining: 756ms
# 269:	learn: 0.1914656	total: 279ms	remaining: 754ms
# 270:	learn: 0.1905602	total: 279ms	remaining: 751ms
# 271:	learn: 0.1896351	total: 280ms	remaining: 749ms
# 272:	learn: 0.1887393	total: 280ms	remaining: 747ms
# 273:	learn: 0.1878036	total: 281ms	remaining: 745ms
# 274:	learn: 0.1868925	total: 282ms	remaining: 742ms
# 275:	learn: 0.1860053	total: 282ms	remaining: 740ms
# 276:	learn: 0.1851601	total: 283ms	remaining: 738ms
# 277:	learn: 0.1843312	total: 283ms	remaining: 736ms
# 278:	learn: 0.1834179	total: 284ms	remaining: 733ms
# 279:	learn: 0.1825479	total: 284ms	remaining: 731ms
# 280:	learn: 0.1816826	total: 285ms	remaining: 729ms
# 281:	learn: 0.1807828	total: 285ms	remaining: 727ms
# 282:	learn: 0.1798877	total: 286ms	remaining: 725ms
# 283:	learn: 0.1790409	total: 287ms	remaining: 722ms
# 284:	learn: 0.1781548	total: 287ms	remaining: 720ms
# 285:	learn: 0.1772733	total: 288ms	remaining: 718ms
# 286:	learn: 0.1763964	total: 288ms	remaining: 716ms
# 287:	learn: 0.1755612	total: 289ms	remaining: 714ms
# 288:	learn: 0.1746931	total: 289ms	remaining: 712ms
# 289:	learn: 0.1738295	total: 290ms	remaining: 710ms
# 290:	learn: 0.1729705	total: 291ms	remaining: 708ms
# 291:	learn: 0.1721578	total: 291ms	remaining: 706ms
# 292:	learn: 0.1713494	total: 292ms	remaining: 704ms
# 293:	learn: 0.1705454	total: 292ms	remaining: 701ms
# 294:	learn: 0.1697031	total: 293ms	remaining: 699ms
# 295:	learn: 0.1688653	total: 293ms	remaining: 697ms
# 296:	learn: 0.1680319	total: 294ms	remaining: 695ms
# 297:	learn: 0.1672442	total: 294ms	remaining: 693ms
# 298:	learn: 0.1664192	total: 295ms	remaining: 691ms
# 299:	learn: 0.1655985	total: 295ms	remaining: 689ms
# 300:	learn: 0.1647848	total: 296ms	remaining: 687ms
# 301:	learn: 0.1639727	total: 296ms	remaining: 685ms
# 302:	learn: 0.1631648	total: 297ms	remaining: 683ms
# 303:	learn: 0.1623612	total: 298ms	remaining: 681ms
# 304:	learn: 0.1615619	total: 298ms	remaining: 680ms
# 305:	learn: 0.1607667	total: 299ms	remaining: 678ms
# 306:	learn: 0.1599782	total: 299ms	remaining: 676ms
# 307:	learn: 0.1591913	total: 300ms	remaining: 674ms
# 308:	learn: 0.1584086	total: 301ms	remaining: 672ms
# 309:	learn: 0.1576300	total: 301ms	remaining: 670ms
# 310:	learn: 0.1568929	total: 302ms	remaining: 668ms
# 311:	learn: 0.1561222	total: 302ms	remaining: 666ms
# 312:	learn: 0.1553554	total: 303ms	remaining: 664ms
# 313:	learn: 0.1545951	total: 303ms	remaining: 663ms
# 314:	learn: 0.1538386	total: 304ms	remaining: 661ms
# 315:	learn: 0.1530839	total: 304ms	remaining: 659ms
# 316:	learn: 0.1523332	total: 305ms	remaining: 657ms
# 317:	learn: 0.1515864	total: 306ms	remaining: 655ms
# 318:	learn: 0.1508435	total: 306ms	remaining: 653ms
# 319:	learn: 0.1501045	total: 307ms	remaining: 652ms
# 320:	learn: 0.1493715	total: 307ms	remaining: 650ms
# 321:	learn: 0.1486424	total: 308ms	remaining: 648ms
# 322:	learn: 0.1479149	total: 308ms	remaining: 646ms
# 323:	learn: 0.1471914	total: 309ms	remaining: 645ms
# 324:	learn: 0.1464716	total: 310ms	remaining: 643ms
# 325:	learn: 0.1457576	total: 310ms	remaining: 641ms
# 326:	learn: 0.1450785	total: 311ms	remaining: 640ms
# 327:	learn: 0.1443717	total: 311ms	remaining: 638ms
# 328:	learn: 0.1436666	total: 312ms	remaining: 636ms
# 329:	learn: 0.1429653	total: 313ms	remaining: 635ms
# 330:	learn: 0.1422676	total: 313ms	remaining: 633ms
# 331:	learn: 0.1415737	total: 314ms	remaining: 631ms
# 332:	learn: 0.1408834	total: 314ms	remaining: 630ms
# 333:	learn: 0.1401967	total: 315ms	remaining: 628ms
# 334:	learn: 0.1395137	total: 315ms	remaining: 626ms
# 335:	learn: 0.1388360	total: 316ms	remaining: 624ms
# 336:	learn: 0.1381601	total: 317ms	remaining: 623ms
# 337:	learn: 0.1374878	total: 317ms	remaining: 621ms
# 338:	learn: 0.1368207	total: 318ms	remaining: 619ms
# 339:	learn: 0.1361555	total: 318ms	remaining: 618ms
# 340:	learn: 0.1354938	total: 319ms	remaining: 616ms
# 341:	learn: 0.1348355	total: 319ms	remaining: 614ms
# 342:	learn: 0.1341808	total: 320ms	remaining: 613ms
# 343:	learn: 0.1335295	total: 320ms	remaining: 611ms
# 344:	learn: 0.1328817	total: 321ms	remaining: 610ms
# 345:	learn: 0.1322387	total: 322ms	remaining: 608ms
# 346:	learn: 0.1315977	total: 322ms	remaining: 607ms
# 347:	learn: 0.1309600	total: 323ms	remaining: 605ms
# 348:	learn: 0.1303258	total: 324ms	remaining: 604ms
# 349:	learn: 0.1296948	total: 324ms	remaining: 602ms
# 350:	learn: 0.1290946	total: 325ms	remaining: 601ms
# 351:	learn: 0.1284702	total: 326ms	remaining: 600ms
# 352:	learn: 0.1278490	total: 326ms	remaining: 598ms
# 353:	learn: 0.1272311	total: 327ms	remaining: 597ms
# 354:	learn: 0.1266178	total: 328ms	remaining: 596ms
# 355:	learn: 0.1260076	total: 329ms	remaining: 594ms
# 356:	learn: 0.1254007	total: 329ms	remaining: 593ms
# 357:	learn: 0.1247970	total: 330ms	remaining: 591ms
# 358:	learn: 0.1241953	total: 330ms	remaining: 590ms
# 359:	learn: 0.1235967	total: 331ms	remaining: 588ms
# 360:	learn: 0.1230013	total: 332ms	remaining: 587ms
# 361:	learn: 0.1224090	total: 332ms	remaining: 585ms
# 362:	learn: 0.1218211	total: 333ms	remaining: 584ms
# 363:	learn: 0.1212363	total: 333ms	remaining: 582ms
# 364:	learn: 0.1206545	total: 334ms	remaining: 581ms
# 365:	learn: 0.1200747	total: 334ms	remaining: 579ms
# 366:	learn: 0.1194979	total: 335ms	remaining: 578ms
# 367:	learn: 0.1189243	total: 336ms	remaining: 576ms
# 368:	learn: 0.1183537	total: 336ms	remaining: 575ms
# 369:	learn: 0.1177861	total: 337ms	remaining: 573ms
# 370:	learn: 0.1172215	total: 337ms	remaining: 572ms
# 371:	learn: 0.1166610	total: 338ms	remaining: 571ms
# 372:	learn: 0.1161024	total: 339ms	remaining: 569ms
# 373:	learn: 0.1155468	total: 339ms	remaining: 568ms
# 374:	learn: 0.1149942	total: 340ms	remaining: 566ms
# 375:	learn: 0.1144445	total: 340ms	remaining: 565ms
# 376:	learn: 0.1138977	total: 341ms	remaining: 564ms
# 377:	learn: 0.1133539	total: 342ms	remaining: 562ms
# 378:	learn: 0.1128129	total: 342ms	remaining: 561ms
# 379:	learn: 0.1122749	total: 343ms	remaining: 559ms
# 380:	learn: 0.1117397	total: 343ms	remaining: 558ms
# 381:	learn: 0.1112074	total: 344ms	remaining: 556ms
# 382:	learn: 0.1106779	total: 344ms	remaining: 555ms
# 383:	learn: 0.1101513	total: 345ms	remaining: 554ms
# 384:	learn: 0.1096282	total: 346ms	remaining: 552ms
# 385:	learn: 0.1091080	total: 347ms	remaining: 551ms
# 386:	learn: 0.1085897	total: 347ms	remaining: 550ms
# 387:	learn: 0.1080750	total: 348ms	remaining: 549ms
# 388:	learn: 0.1075630	total: 349ms	remaining: 547ms
# 389:	learn: 0.1070530	total: 349ms	remaining: 546ms
# 390:	learn: 0.1065464	total: 350ms	remaining: 545ms
# 391:	learn: 0.1060418	total: 351ms	remaining: 544ms
# 392:	learn: 0.1055400	total: 351ms	remaining: 542ms
# 393:	learn: 0.1050408	total: 352ms	remaining: 541ms
# 394:	learn: 0.1045450	total: 353ms	remaining: 541ms
# 395:	learn: 0.1040512	total: 354ms	remaining: 540ms
# 396:	learn: 0.1035600	total: 354ms	remaining: 538ms
# 397:	learn: 0.1030714	total: 355ms	remaining: 537ms
# 398:	learn: 0.1025862	total: 356ms	remaining: 536ms
# 399:	learn: 0.1021029	total: 356ms	remaining: 534ms
# 400:	learn: 0.1015413	total: 357ms	remaining: 533ms
# 401:	learn: 0.1010639	total: 358ms	remaining: 532ms
# 402:	learn: 0.1005884	total: 358ms	remaining: 531ms
# 403:	learn: 0.1000356	total: 359ms	remaining: 530ms
# 404:	learn: 0.0995679	total: 360ms	remaining: 528ms
# 405:	learn: 0.0990999	total: 360ms	remaining: 527ms
# 406:	learn: 0.0985557	total: 361ms	remaining: 526ms
# 407:	learn: 0.0980928	total: 361ms	remaining: 524ms
# 408:	learn: 0.0975546	total: 362ms	remaining: 523ms
# 409:	learn: 0.0970197	total: 363ms	remaining: 522ms
# 410:	learn: 0.0964881	total: 363ms	remaining: 521ms
# 411:	learn: 0.0960357	total: 364ms	remaining: 519ms
# 412:	learn: 0.0955100	total: 364ms	remaining: 518ms
# 413:	learn: 0.0950620	total: 365ms	remaining: 517ms
# 414:	learn: 0.0946169	total: 366ms	remaining: 515ms
# 415:	learn: 0.0940993	total: 366ms	remaining: 514ms
# 416:	learn: 0.0935849	total: 367ms	remaining: 513ms
# 417:	learn: 0.0931470	total: 367ms	remaining: 511ms
# 418:	learn: 0.0926382	total: 368ms	remaining: 510ms
# 419:	learn: 0.0921326	total: 369ms	remaining: 509ms
# 420:	learn: 0.0916301	total: 369ms	remaining: 508ms
# 421:	learn: 0.0911307	total: 370ms	remaining: 506ms
# 422:	learn: 0.0906344	total: 370ms	remaining: 505ms
# 423:	learn: 0.0901412	total: 371ms	remaining: 504ms
# 424:	learn: 0.0896510	total: 371ms	remaining: 502ms
# 425:	learn: 0.0891638	total: 372ms	remaining: 501ms
# 426:	learn: 0.0886797	total: 372ms	remaining: 500ms
# 427:	learn: 0.0881985	total: 373ms	remaining: 498ms
# 428:	learn: 0.0877203	total: 374ms	remaining: 497ms
# 429:	learn: 0.0872450	total: 374ms	remaining: 496ms
# 430:	learn: 0.0867727	total: 375ms	remaining: 495ms
# 431:	learn: 0.0863032	total: 375ms	remaining: 493ms
# 432:	learn: 0.0858367	total: 376ms	remaining: 492ms
# 433:	learn: 0.0853730	total: 376ms	remaining: 491ms
# 434:	learn: 0.0849121	total: 377ms	remaining: 490ms
# 435:	learn: 0.0844541	total: 378ms	remaining: 488ms
# 436:	learn: 0.0839989	total: 378ms	remaining: 487ms
# 437:	learn: 0.0835465	total: 379ms	remaining: 486ms
# 438:	learn: 0.0830968	total: 379ms	remaining: 485ms
# 439:	learn: 0.0826499	total: 380ms	remaining: 483ms
# 440:	learn: 0.0822057	total: 380ms	remaining: 482ms
# 441:	learn: 0.0817642	total: 381ms	remaining: 481ms
# 442:	learn: 0.0813254	total: 382ms	remaining: 480ms
# 443:	learn: 0.0808893	total: 382ms	remaining: 479ms
# 444:	learn: 0.0804559	total: 383ms	remaining: 477ms
# 445:	learn: 0.0800251	total: 383ms	remaining: 476ms
# 446:	learn: 0.0795969	total: 384ms	remaining: 475ms
# 447:	learn: 0.0791713	total: 384ms	remaining: 474ms
# 448:	learn: 0.0787483	total: 385ms	remaining: 472ms
# 449:	learn: 0.0783279	total: 386ms	remaining: 471ms
# 450:	learn: 0.0779100	total: 386ms	remaining: 470ms
# 451:	learn: 0.0774946	total: 387ms	remaining: 469ms
# 452:	learn: 0.0770818	total: 387ms	remaining: 468ms
# 453:	learn: 0.0766715	total: 388ms	remaining: 466ms
# 454:	learn: 0.0762636	total: 388ms	remaining: 465ms
# 455:	learn: 0.0758582	total: 389ms	remaining: 464ms
# 456:	learn: 0.0754553	total: 389ms	remaining: 463ms
# 457:	learn: 0.0750548	total: 390ms	remaining: 462ms
# 458:	learn: 0.0746567	total: 391ms	remaining: 460ms
# 459:	learn: 0.0742611	total: 391ms	remaining: 459ms
# 460:	learn: 0.0738678	total: 392ms	remaining: 458ms
# 461:	learn: 0.0735217	total: 392ms	remaining: 457ms
# 462:	learn: 0.0731823	total: 393ms	remaining: 456ms
# 463:	learn: 0.0728449	total: 393ms	remaining: 454ms
# 464:	learn: 0.0725043	total: 394ms	remaining: 453ms
# 465:	learn: 0.0721204	total: 394ms	remaining: 452ms
# 466:	learn: 0.0717832	total: 395ms	remaining: 451ms
# 467:	learn: 0.0714477	total: 396ms	remaining: 450ms
# 468:	learn: 0.0710695	total: 396ms	remaining: 448ms
# 469:	learn: 0.0707424	total: 397ms	remaining: 447ms
# 470:	learn: 0.0704121	total: 397ms	remaining: 446ms
# 471:	learn: 0.0700833	total: 398ms	remaining: 445ms
# 472:	learn: 0.0697123	total: 398ms	remaining: 444ms
# 473:	learn: 0.0693869	total: 399ms	remaining: 443ms
# 474:	learn: 0.0690632	total: 399ms	remaining: 441ms
# 475:	learn: 0.0686976	total: 400ms	remaining: 440ms
# 476:	learn: 0.0683822	total: 400ms	remaining: 439ms
# 477:	learn: 0.0680633	total: 401ms	remaining: 438ms
# 478:	learn: 0.0677461	total: 402ms	remaining: 437ms
# 479:	learn: 0.0674304	total: 402ms	remaining: 436ms
# 480:	learn: 0.0671165	total: 403ms	remaining: 435ms
# 481:	learn: 0.0667611	total: 403ms	remaining: 433ms
# 482:	learn: 0.0664078	total: 404ms	remaining: 432ms
# 483:	learn: 0.0660984	total: 404ms	remaining: 431ms
# 484:	learn: 0.0657906	total: 405ms	remaining: 430ms
# 485:	learn: 0.0654426	total: 406ms	remaining: 429ms
# 486:	learn: 0.0651380	total: 406ms	remaining: 428ms
# 487:	learn: 0.0647935	total: 407ms	remaining: 427ms
# 488:	learn: 0.0644918	total: 407ms	remaining: 426ms
# 489:	learn: 0.0641971	total: 408ms	remaining: 424ms
# 490:	learn: 0.0638985	total: 408ms	remaining: 423ms
# 491:	learn: 0.0635606	total: 409ms	remaining: 422ms
# 492:	learn: 0.0632353	total: 409ms	remaining: 421ms
# 493:	learn: 0.0629119	total: 410ms	remaining: 420ms
# 494:	learn: 0.0625904	total: 411ms	remaining: 419ms
# 495:	learn: 0.0622708	total: 411ms	remaining: 418ms
# 496:	learn: 0.0619532	total: 412ms	remaining: 417ms
# 497:	learn: 0.0616374	total: 412ms	remaining: 416ms
# 498:	learn: 0.0613234	total: 413ms	remaining: 414ms
# 499:	learn: 0.0610113	total: 413ms	remaining: 413ms
# 500:	learn: 0.0607010	total: 414ms	remaining: 412ms
# 501:	learn: 0.0603926	total: 414ms	remaining: 411ms
# 502:	learn: 0.0600859	total: 415ms	remaining: 410ms
# 503:	learn: 0.0597811	total: 416ms	remaining: 409ms
# 504:	learn: 0.0594780	total: 416ms	remaining: 408ms
# 505:	learn: 0.0591768	total: 417ms	remaining: 407ms
# 506:	learn: 0.0588772	total: 417ms	remaining: 406ms
# 507:	learn: 0.0585794	total: 418ms	remaining: 405ms
# 508:	learn: 0.0582834	total: 418ms	remaining: 404ms
# 509:	learn: 0.0579891	total: 419ms	remaining: 403ms
# 510:	learn: 0.0576964	total: 420ms	remaining: 402ms
# 511:	learn: 0.0574055	total: 420ms	remaining: 400ms
# 512:	learn: 0.0571163	total: 421ms	remaining: 399ms
# 513:	learn: 0.0568287	total: 421ms	remaining: 398ms
# 514:	learn: 0.0565428	total: 422ms	remaining: 397ms
# 515:	learn: 0.0562586	total: 422ms	remaining: 396ms
# 516:	learn: 0.0559760	total: 423ms	remaining: 395ms
# 517:	learn: 0.0556950	total: 424ms	remaining: 394ms
# 518:	learn: 0.0554157	total: 424ms	remaining: 393ms
# 519:	learn: 0.0551379	total: 425ms	remaining: 392ms
# 520:	learn: 0.0548618	total: 425ms	remaining: 391ms
# 521:	learn: 0.0545872	total: 426ms	remaining: 390ms
# 522:	learn: 0.0543398	total: 426ms	remaining: 389ms
# 523:	learn: 0.0540682	total: 427ms	remaining: 388ms
# 524:	learn: 0.0537981	total: 427ms	remaining: 387ms
# 525:	learn: 0.0535295	total: 428ms	remaining: 386ms
# 526:	learn: 0.0532625	total: 429ms	remaining: 385ms
# 527:	learn: 0.0529970	total: 429ms	remaining: 384ms
# 528:	learn: 0.0527330	total: 430ms	remaining: 383ms
# 529:	learn: 0.0524705	total: 430ms	remaining: 381ms
# 530:	learn: 0.0522095	total: 431ms	remaining: 380ms
# 531:	learn: 0.0519501	total: 431ms	remaining: 379ms
# 532:	learn: 0.0516921	total: 432ms	remaining: 378ms
# 533:	learn: 0.0514355	total: 432ms	remaining: 377ms
# 534:	learn: 0.0511805	total: 433ms	remaining: 376ms
# 535:	learn: 0.0509268	total: 434ms	remaining: 375ms
# 536:	learn: 0.0506747	total: 434ms	remaining: 374ms
# 537:	learn: 0.0504239	total: 435ms	remaining: 373ms
# 538:	learn: 0.0501746	total: 435ms	remaining: 372ms
# 539:	learn: 0.0499267	total: 436ms	remaining: 371ms
# 540:	learn: 0.0496802	total: 436ms	remaining: 370ms
# 541:	learn: 0.0494351	total: 437ms	remaining: 369ms
# 542:	learn: 0.0491914	total: 438ms	remaining: 368ms
# 543:	learn: 0.0489491	total: 438ms	remaining: 367ms
# 544:	learn: 0.0487081	total: 439ms	remaining: 366ms
# 545:	learn: 0.0484686	total: 440ms	remaining: 366ms
# 546:	learn: 0.0482303	total: 440ms	remaining: 365ms
# 547:	learn: 0.0479934	total: 441ms	remaining: 364ms
# 548:	learn: 0.0477579	total: 442ms	remaining: 363ms
# 549:	learn: 0.0475237	total: 442ms	remaining: 362ms
# 550:	learn: 0.0472908	total: 443ms	remaining: 361ms
# 551:	learn: 0.0470592	total: 443ms	remaining: 360ms
# 552:	learn: 0.0468289	total: 444ms	remaining: 359ms
# 553:	learn: 0.0465999	total: 444ms	remaining: 358ms
# 554:	learn: 0.0463722	total: 445ms	remaining: 357ms
# 555:	learn: 0.0461458	total: 446ms	remaining: 356ms
# 556:	learn: 0.0459207	total: 446ms	remaining: 355ms
# 557:	learn: 0.0456968	total: 447ms	remaining: 354ms
# 558:	learn: 0.0454742	total: 447ms	remaining: 353ms
# 559:	learn: 0.0452529	total: 448ms	remaining: 352ms
# 560:	learn: 0.0450328	total: 449ms	remaining: 351ms
# 561:	learn: 0.0448139	total: 449ms	remaining: 350ms
# 562:	learn: 0.0445962	total: 450ms	remaining: 349ms
# 563:	learn: 0.0443798	total: 450ms	remaining: 348ms
# 564:	learn: 0.0441646	total: 451ms	remaining: 347ms
# 565:	learn: 0.0439506	total: 452ms	remaining: 346ms
# 566:	learn: 0.0437378	total: 452ms	remaining: 345ms
# 567:	learn: 0.0435262	total: 453ms	remaining: 344ms
# 568:	learn: 0.0433158	total: 454ms	remaining: 344ms
# 569:	learn: 0.0431066	total: 454ms	remaining: 343ms
# 570:	learn: 0.0428985	total: 455ms	remaining: 342ms
# 571:	learn: 0.0426916	total: 455ms	remaining: 341ms
# 572:	learn: 0.0424858	total: 456ms	remaining: 340ms
# 573:	learn: 0.0422813	total: 457ms	remaining: 339ms
# 574:	learn: 0.0420778	total: 457ms	remaining: 338ms
# 575:	learn: 0.0418755	total: 458ms	remaining: 337ms
# 576:	learn: 0.0416743	total: 458ms	remaining: 336ms
# 577:	learn: 0.0414743	total: 459ms	remaining: 335ms
# 578:	learn: 0.0412754	total: 459ms	remaining: 334ms
# 579:	learn: 0.0410776	total: 460ms	remaining: 333ms
# 580:	learn: 0.0408809	total: 461ms	remaining: 332ms
# 581:	learn: 0.0406584	total: 461ms	remaining: 331ms
# 582:	learn: 0.0404374	total: 462ms	remaining: 330ms
# 583:	learn: 0.0402437	total: 462ms	remaining: 329ms
# 584:	learn: 0.0400249	total: 463ms	remaining: 328ms
# 585:	learn: 0.0398075	total: 464ms	remaining: 328ms
# 586:	learn: 0.0395915	total: 464ms	remaining: 327ms
# 587:	learn: 0.0394017	total: 465ms	remaining: 326ms
# 588:	learn: 0.0391880	total: 466ms	remaining: 325ms
# 589:	learn: 0.0389755	total: 467ms	remaining: 325ms
# 590:	learn: 0.0387644	total: 468ms	remaining: 324ms
# 591:	learn: 0.0385784	total: 468ms	remaining: 323ms
# 592:	learn: 0.0383695	total: 469ms	remaining: 322ms
# 593:	learn: 0.0381619	total: 469ms	remaining: 321ms
# 594:	learn: 0.0379555	total: 470ms	remaining: 320ms
# 595:	learn: 0.0377505	total: 471ms	remaining: 319ms
# 596:	learn: 0.0375467	total: 471ms	remaining: 318ms
# 597:	learn: 0.0373441	total: 472ms	remaining: 317ms
# 598:	learn: 0.0371645	total: 472ms	remaining: 316ms
# 599:	learn: 0.0369641	total: 473ms	remaining: 315ms
# 600:	learn: 0.0367649	total: 474ms	remaining: 314ms
# 601:	learn: 0.0365881	total: 474ms	remaining: 313ms
# 602:	learn: 0.0363910	total: 475ms	remaining: 313ms
# 603:	learn: 0.0362004	total: 475ms	remaining: 312ms
# 604:	learn: 0.0360110	total: 476ms	remaining: 311ms
# 605:	learn: 0.0358377	total: 476ms	remaining: 310ms
# 606:	learn: 0.0356502	total: 477ms	remaining: 309ms
# 607:	learn: 0.0354639	total: 478ms	remaining: 308ms
# 608:	learn: 0.0352787	total: 478ms	remaining: 307ms
# 609:	learn: 0.0351088	total: 479ms	remaining: 306ms
# 610:	learn: 0.0349255	total: 479ms	remaining: 305ms
# 611:	learn: 0.0347433	total: 480ms	remaining: 304ms
# 612:	learn: 0.0345622	total: 480ms	remaining: 303ms
# 613:	learn: 0.0343822	total: 481ms	remaining: 302ms
# 614:	learn: 0.0342165	total: 482ms	remaining: 301ms
# 615:	learn: 0.0340383	total: 482ms	remaining: 301ms
# 616:	learn: 0.0338612	total: 483ms	remaining: 300ms
# 617:	learn: 0.0336980	total: 483ms	remaining: 299ms
# 618:	learn: 0.0335228	total: 484ms	remaining: 298ms
# 619:	learn: 0.0333485	total: 484ms	remaining: 297ms
# 620:	learn: 0.0331753	total: 485ms	remaining: 296ms
# 621:	learn: 0.0330031	total: 485ms	remaining: 295ms
# 622:	learn: 0.0328320	total: 486ms	remaining: 294ms
# 623:	learn: 0.0326618	total: 487ms	remaining: 293ms
# 624:	learn: 0.0325086	total: 487ms	remaining: 292ms
# 625:	learn: 0.0323403	total: 488ms	remaining: 291ms
# 626:	learn: 0.0321729	total: 488ms	remaining: 291ms
# 627:	learn: 0.0320066	total: 489ms	remaining: 290ms
# 628:	learn: 0.0318412	total: 490ms	remaining: 289ms
# 629:	learn: 0.0316768	total: 490ms	remaining: 288ms
# 630:	learn: 0.0315133	total: 491ms	remaining: 287ms
# 631:	learn: 0.0313508	total: 491ms	remaining: 286ms
# 632:	learn: 0.0311893	total: 492ms	remaining: 285ms
# 633:	learn: 0.0310287	total: 492ms	remaining: 284ms
# 634:	learn: 0.0308690	total: 493ms	remaining: 283ms
# 635:	learn: 0.0307103	total: 494ms	remaining: 282ms
# 636:	learn: 0.0305525	total: 494ms	remaining: 282ms
# 637:	learn: 0.0303956	total: 495ms	remaining: 281ms
# 638:	learn: 0.0302396	total: 495ms	remaining: 280ms
# 639:	learn: 0.0300846	total: 496ms	remaining: 279ms
# 640:	learn: 0.0299304	total: 496ms	remaining: 278ms
# 641:	learn: 0.0297772	total: 497ms	remaining: 277ms
# 642:	learn: 0.0296248	total: 497ms	remaining: 276ms
# 643:	learn: 0.0294733	total: 498ms	remaining: 275ms
# 644:	learn: 0.0293227	total: 499ms	remaining: 274ms
# 645:	learn: 0.0291730	total: 499ms	remaining: 274ms
# 646:	learn: 0.0290241	total: 500ms	remaining: 273ms
# 647:	learn: 0.0288761	total: 500ms	remaining: 272ms
# 648:	learn: 0.0287290	total: 501ms	remaining: 271ms
# 649:	learn: 0.0285827	total: 501ms	remaining: 270ms
# 650:	learn: 0.0284372	total: 502ms	remaining: 269ms
# 651:	learn: 0.0282926	total: 502ms	remaining: 268ms
# 652:	learn: 0.0281489	total: 503ms	remaining: 267ms
# 653:	learn: 0.0280059	total: 504ms	remaining: 266ms
# 654:	learn: 0.0278638	total: 504ms	remaining: 266ms
# 655:	learn: 0.0277225	total: 505ms	remaining: 265ms
# 656:	learn: 0.0275820	total: 505ms	remaining: 264ms
# 657:	learn: 0.0274423	total: 506ms	remaining: 263ms
# 658:	learn: 0.0273034	total: 507ms	remaining: 262ms
# 659:	learn: 0.0271653	total: 507ms	remaining: 261ms
# 660:	learn: 0.0270280	total: 508ms	remaining: 260ms
# 661:	learn: 0.0268915	total: 508ms	remaining: 260ms
# 662:	learn: 0.0267558	total: 509ms	remaining: 259ms
# 663:	learn: 0.0266208	total: 509ms	remaining: 258ms
# 664:	learn: 0.0264867	total: 510ms	remaining: 257ms
# 665:	learn: 0.0263533	total: 511ms	remaining: 256ms
# 666:	learn: 0.0262206	total: 511ms	remaining: 255ms
# 667:	learn: 0.0260887	total: 512ms	remaining: 254ms
# 668:	learn: 0.0259576	total: 512ms	remaining: 253ms
# 669:	learn: 0.0258272	total: 513ms	remaining: 253ms
# 670:	learn: 0.0256975	total: 513ms	remaining: 252ms
# 671:	learn: 0.0255686	total: 514ms	remaining: 251ms
# 672:	learn: 0.0254405	total: 515ms	remaining: 250ms
# 673:	learn: 0.0253130	total: 515ms	remaining: 249ms
# 674:	learn: 0.0251863	total: 516ms	remaining: 248ms
# 675:	learn: 0.0250603	total: 516ms	remaining: 247ms
# 676:	learn: 0.0249350	total: 517ms	remaining: 247ms
# 677:	learn: 0.0248105	total: 517ms	remaining: 246ms
# 678:	learn: 0.0246866	total: 518ms	remaining: 245ms
# 679:	learn: 0.0245635	total: 519ms	remaining: 244ms
# 680:	learn: 0.0244410	total: 519ms	remaining: 243ms
# 681:	learn: 0.0243192	total: 520ms	remaining: 242ms
# 682:	learn: 0.0241982	total: 520ms	remaining: 241ms
# 683:	learn: 0.0240778	total: 521ms	remaining: 241ms
# 684:	learn: 0.0239581	total: 521ms	remaining: 240ms
# 685:	learn: 0.0238391	total: 522ms	remaining: 239ms
# 686:	learn: 0.0237207	total: 523ms	remaining: 238ms
# 687:	learn: 0.0236030	total: 523ms	remaining: 237ms
# 688:	learn: 0.0234860	total: 524ms	remaining: 236ms
# 689:	learn: 0.0233697	total: 524ms	remaining: 236ms
# 690:	learn: 0.0232540	total: 525ms	remaining: 235ms
# 691:	learn: 0.0231389	total: 525ms	remaining: 234ms
# 692:	learn: 0.0230245	total: 526ms	remaining: 233ms
# 693:	learn: 0.0229108	total: 527ms	remaining: 232ms
# 694:	learn: 0.0227977	total: 527ms	remaining: 231ms
# 695:	learn: 0.0226852	total: 528ms	remaining: 230ms
# 696:	learn: 0.0225734	total: 528ms	remaining: 230ms
# 697:	learn: 0.0224622	total: 529ms	remaining: 229ms
# 698:	learn: 0.0223516	total: 529ms	remaining: 228ms
# 699:	learn: 0.0222417	total: 530ms	remaining: 227ms
# 700:	learn: 0.0221323	total: 530ms	remaining: 226ms
# 701:	learn: 0.0220236	total: 531ms	remaining: 225ms
# 702:	learn: 0.0219155	total: 532ms	remaining: 225ms
# 703:	learn: 0.0218080	total: 532ms	remaining: 224ms
# 704:	learn: 0.0217011	total: 533ms	remaining: 223ms
# 705:	learn: 0.0215948	total: 533ms	remaining: 222ms
# 706:	learn: 0.0214892	total: 534ms	remaining: 221ms
# 707:	learn: 0.0213841	total: 534ms	remaining: 220ms
# 708:	learn: 0.0212796	total: 535ms	remaining: 220ms
# 709:	learn: 0.0211756	total: 536ms	remaining: 219ms
# 710:	learn: 0.0210723	total: 536ms	remaining: 218ms
# 711:	learn: 0.0209696	total: 537ms	remaining: 217ms
# 712:	learn: 0.0208674	total: 537ms	remaining: 216ms
# 713:	learn: 0.0207658	total: 538ms	remaining: 215ms
# 714:	learn: 0.0206648	total: 538ms	remaining: 215ms
# 715:	learn: 0.0205643	total: 539ms	remaining: 214ms
# 716:	learn: 0.0204644	total: 540ms	remaining: 213ms
# 717:	learn: 0.0203651	total: 540ms	remaining: 212ms
# 718:	learn: 0.0202663	total: 541ms	remaining: 211ms
# 719:	learn: 0.0201681	total: 541ms	remaining: 210ms
# 720:	learn: 0.0200705	total: 542ms	remaining: 210ms
# 721:	learn: 0.0199733	total: 542ms	remaining: 209ms
# 722:	learn: 0.0198768	total: 543ms	remaining: 208ms
# 723:	learn: 0.0197807	total: 544ms	remaining: 207ms
# 724:	learn: 0.0196853	total: 544ms	remaining: 206ms
# 725:	learn: 0.0195903	total: 545ms	remaining: 206ms
# 726:	learn: 0.0194959	total: 545ms	remaining: 205ms
# 727:	learn: 0.0194020	total: 546ms	remaining: 204ms
# 728:	learn: 0.0193086	total: 547ms	remaining: 203ms
# 729:	learn: 0.0192158	total: 548ms	remaining: 203ms
# 730:	learn: 0.0191235	total: 548ms	remaining: 202ms
# 731:	learn: 0.0190317	total: 549ms	remaining: 201ms
# 732:	learn: 0.0189404	total: 550ms	remaining: 200ms
# 733:	learn: 0.0188497	total: 550ms	remaining: 199ms
# 734:	learn: 0.0187594	total: 551ms	remaining: 199ms
# 735:	learn: 0.0186696	total: 551ms	remaining: 198ms
# 736:	learn: 0.0185804	total: 552ms	remaining: 197ms
# 737:	learn: 0.0184917	total: 553ms	remaining: 196ms
# 738:	learn: 0.0184034	total: 553ms	remaining: 195ms
# 739:	learn: 0.0183157	total: 554ms	remaining: 195ms
# 740:	learn: 0.0182284	total: 555ms	remaining: 194ms
# 741:	learn: 0.0181417	total: 555ms	remaining: 193ms
# 742:	learn: 0.0180554	total: 556ms	remaining: 192ms
# 743:	learn: 0.0179696	total: 556ms	remaining: 191ms
# 744:	learn: 0.0178875	total: 557ms	remaining: 191ms
# 745:	learn: 0.0178027	total: 558ms	remaining: 190ms
# 746:	learn: 0.0177182	total: 559ms	remaining: 189ms
# 747:	learn: 0.0176343	total: 559ms	remaining: 188ms
# 748:	learn: 0.0175540	total: 560ms	remaining: 188ms
# 749:	learn: 0.0174723	total: 560ms	remaining: 187ms
# 750:	learn: 0.0173910	total: 561ms	remaining: 186ms
# 751:	learn: 0.0173102	total: 562ms	remaining: 185ms
# 752:	learn: 0.0172298	total: 562ms	remaining: 184ms
# 753:	learn: 0.0171497	total: 563ms	remaining: 184ms
# 754:	learn: 0.0170701	total: 563ms	remaining: 183ms
# 755:	learn: 0.0169909	total: 564ms	remaining: 182ms
# 756:	learn: 0.0169121	total: 565ms	remaining: 181ms
# 757:	learn: 0.0168337	total: 565ms	remaining: 180ms
# 758:	learn: 0.0167557	total: 566ms	remaining: 180ms
# 759:	learn: 0.0166782	total: 566ms	remaining: 179ms
# 760:	learn: 0.0166010	total: 567ms	remaining: 178ms
# 761:	learn: 0.0165242	total: 567ms	remaining: 177ms
# 762:	learn: 0.0164478	total: 568ms	remaining: 176ms
# 763:	learn: 0.0163717	total: 569ms	remaining: 176ms
# 764:	learn: 0.0162961	total: 569ms	remaining: 175ms
# 765:	learn: 0.0162209	total: 570ms	remaining: 174ms
# 766:	learn: 0.0161460	total: 570ms	remaining: 173ms
# 767:	learn: 0.0160715	total: 571ms	remaining: 172ms
# 768:	learn: 0.0159975	total: 571ms	remaining: 172ms
# 769:	learn: 0.0159237	total: 572ms	remaining: 171ms
# 770:	learn: 0.0158504	total: 573ms	remaining: 170ms
# 771:	learn: 0.0157775	total: 573ms	remaining: 169ms
# 772:	learn: 0.0157049	total: 574ms	remaining: 168ms
# 773:	learn: 0.0156327	total: 574ms	remaining: 168ms
# 774:	learn: 0.0155608	total: 575ms	remaining: 167ms
# 775:	learn: 0.0154893	total: 575ms	remaining: 166ms
# 776:	learn: 0.0154182	total: 576ms	remaining: 165ms
# 777:	learn: 0.0153475	total: 577ms	remaining: 165ms
# 778:	learn: 0.0152771	total: 577ms	remaining: 164ms
# 779:	learn: 0.0152071	total: 578ms	remaining: 163ms
# 780:	learn: 0.0151374	total: 578ms	remaining: 162ms
# 781:	learn: 0.0150681	total: 579ms	remaining: 161ms
# 782:	learn: 0.0149992	total: 579ms	remaining: 161ms
# 783:	learn: 0.0149306	total: 580ms	remaining: 160ms
# 784:	learn: 0.0148623	total: 580ms	remaining: 159ms
# 785:	learn: 0.0147944	total: 581ms	remaining: 158ms
# 786:	learn: 0.0147269	total: 582ms	remaining: 157ms
# 787:	learn: 0.0146597	total: 582ms	remaining: 157ms
# 788:	learn: 0.0145928	total: 583ms	remaining: 156ms
# 789:	learn: 0.0145263	total: 583ms	remaining: 155ms
# 790:	learn: 0.0144601	total: 584ms	remaining: 154ms
# 791:	learn: 0.0143943	total: 585ms	remaining: 154ms
# 792:	learn: 0.0143138	total: 585ms	remaining: 153ms
# 793:	learn: 0.0142338	total: 586ms	remaining: 152ms
# 794:	learn: 0.0141543	total: 586ms	remaining: 151ms
# 795:	learn: 0.0140753	total: 587ms	remaining: 150ms
# 796:	learn: 0.0139969	total: 587ms	remaining: 150ms
# 797:	learn: 0.0139189	total: 588ms	remaining: 149ms
# 798:	learn: 0.0138414	total: 589ms	remaining: 148ms
# 799:	learn: 0.0137643	total: 589ms	remaining: 147ms
# 800:	learn: 0.0136878	total: 590ms	remaining: 146ms
# 801:	learn: 0.0136212	total: 590ms	remaining: 146ms
# 802:	learn: 0.0135549	total: 591ms	remaining: 145ms
# 803:	learn: 0.0134796	total: 591ms	remaining: 144ms
# 804:	learn: 0.0134141	total: 592ms	remaining: 143ms
# 805:	learn: 0.0133395	total: 592ms	remaining: 143ms
# 806:	learn: 0.0132804	total: 593ms	remaining: 142ms
# 807:	learn: 0.0132205	total: 593ms	remaining: 141ms
# 808:	learn: 0.0131471	total: 594ms	remaining: 140ms
# 809:	learn: 0.0130888	total: 594ms	remaining: 139ms
# 810:	learn: 0.0130299	total: 595ms	remaining: 139ms
# 811:	learn: 0.0129712	total: 596ms	remaining: 138ms
# 812:	learn: 0.0128991	total: 596ms	remaining: 137ms
# 813:	learn: 0.0128365	total: 597ms	remaining: 136ms
# 814:	learn: 0.0127743	total: 597ms	remaining: 136ms
# 815:	learn: 0.0127083	total: 598ms	remaining: 135ms
# 816:	learn: 0.0126511	total: 599ms	remaining: 134ms
# 817:	learn: 0.0125808	total: 599ms	remaining: 133ms
# 818:	learn: 0.0125198	total: 600ms	remaining: 133ms
# 819:	learn: 0.0124592	total: 600ms	remaining: 132ms
# 820:	learn: 0.0123948	total: 601ms	remaining: 131ms
# 821:	learn: 0.0123392	total: 602ms	remaining: 130ms
# 822:	learn: 0.0122705	total: 602ms	remaining: 129ms
# 823:	learn: 0.0122111	total: 603ms	remaining: 129ms
# 824:	learn: 0.0121521	total: 603ms	remaining: 128ms
# 825:	learn: 0.0120845	total: 604ms	remaining: 127ms
# 826:	learn: 0.0120312	total: 604ms	remaining: 126ms
# 827:	learn: 0.0119772	total: 605ms	remaining: 126ms
# 828:	learn: 0.0119153	total: 606ms	remaining: 125ms
# 829:	learn: 0.0118619	total: 607ms	remaining: 124ms
# 830:	learn: 0.0118046	total: 607ms	remaining: 123ms
# 831:	learn: 0.0117389	total: 608ms	remaining: 123ms
# 832:	learn: 0.0116823	total: 608ms	remaining: 122ms
# 833:	learn: 0.0116219	total: 609ms	remaining: 121ms
# 834:	learn: 0.0115699	total: 609ms	remaining: 120ms
# 835:	learn: 0.0115054	total: 610ms	remaining: 120ms
# 836:	learn: 0.0114500	total: 610ms	remaining: 119ms
# 837:	learn: 0.0113948	total: 611ms	remaining: 118ms
# 838:	learn: 0.0113360	total: 612ms	remaining: 117ms
# 839:	learn: 0.0112852	total: 612ms	remaining: 117ms
# 840:	learn: 0.0112223	total: 613ms	remaining: 116ms
# 841:	learn: 0.0111683	total: 613ms	remaining: 115ms
# 842:	learn: 0.0111061	total: 614ms	remaining: 114ms
# 843:	learn: 0.0110573	total: 614ms	remaining: 114ms
# 844:	learn: 0.0110018	total: 615ms	remaining: 113ms
# 845:	learn: 0.0109466	total: 615ms	remaining: 112ms
# 846:	learn: 0.0108918	total: 616ms	remaining: 111ms
# 847:	learn: 0.0108373	total: 617ms	remaining: 111ms
# 848:	learn: 0.0107831	total: 617ms	remaining: 110ms
# 849:	learn: 0.0107293	total: 618ms	remaining: 109ms
# 850:	learn: 0.0106758	total: 619ms	remaining: 108ms
# 851:	learn: 0.0106227	total: 619ms	remaining: 108ms
# 852:	learn: 0.0105698	total: 620ms	remaining: 107ms
# 853:	learn: 0.0105173	total: 621ms	remaining: 106ms
# 854:	learn: 0.0104652	total: 621ms	remaining: 105ms
# 855:	learn: 0.0104133	total: 622ms	remaining: 105ms
# 856:	learn: 0.0103618	total: 622ms	remaining: 104ms
# 857:	learn: 0.0103105	total: 623ms	remaining: 103ms
# 858:	learn: 0.0102596	total: 623ms	remaining: 102ms
# 859:	learn: 0.0102090	total: 624ms	remaining: 102ms
# 860:	learn: 0.0101587	total: 625ms	remaining: 101ms
# 861:	learn: 0.0101087	total: 625ms	remaining: 100ms
# 862:	learn: 0.0100591	total: 626ms	remaining: 99.4ms
# 863:	learn: 0.0100097	total: 626ms	remaining: 98.6ms
# 864:	learn: 0.0099606	total: 627ms	remaining: 97.9ms
# 865:	learn: 0.0099119	total: 628ms	remaining: 97.1ms
# 866:	learn: 0.0098634	total: 628ms	remaining: 96.4ms
# 867:	learn: 0.0098152	total: 629ms	remaining: 95.6ms
# 868:	learn: 0.0097673	total: 629ms	remaining: 94.9ms
# 869:	learn: 0.0097197	total: 630ms	remaining: 94.1ms
# 870:	learn: 0.0096632	total: 631ms	remaining: 93.4ms
# 871:	learn: 0.0096162	total: 631ms	remaining: 92.6ms
# 872:	learn: 0.0095603	total: 632ms	remaining: 91.9ms
# 873:	learn: 0.0095048	total: 632ms	remaining: 91.2ms
# 874:	learn: 0.0094585	total: 633ms	remaining: 90.4ms
# 875:	learn: 0.0094036	total: 633ms	remaining: 89.7ms
# 876:	learn: 0.0093579	total: 634ms	remaining: 88.9ms
# 877:	learn: 0.0093036	total: 635ms	remaining: 88.2ms
# 878:	learn: 0.0092497	total: 635ms	remaining: 87.4ms
# 879:	learn: 0.0092046	total: 636ms	remaining: 86.7ms
# 880:	learn: 0.0091513	total: 636ms	remaining: 86ms
# 881:	learn: 0.0091068	total: 637ms	remaining: 85.2ms
# 882:	learn: 0.0090541	total: 637ms	remaining: 84.5ms
# 883:	learn: 0.0090017	total: 638ms	remaining: 83.7ms
# 884:	learn: 0.0089579	total: 639ms	remaining: 83ms
# 885:	learn: 0.0089061	total: 639ms	remaining: 82.2ms
# 886:	learn: 0.0088627	total: 640ms	remaining: 81.5ms
# 887:	learn: 0.0088115	total: 640ms	remaining: 80.8ms
# 888:	learn: 0.0087606	total: 641ms	remaining: 80ms
# 889:	learn: 0.0087180	total: 641ms	remaining: 79.3ms
# 890:	learn: 0.0086677	total: 642ms	remaining: 78.5ms
# 891:	learn: 0.0086255	total: 643ms	remaining: 77.8ms
# 892:	learn: 0.0085757	total: 643ms	remaining: 77.1ms
# 893:	learn: 0.0085263	total: 644ms	remaining: 76.3ms
# 894:	learn: 0.0084848	total: 644ms	remaining: 75.6ms
# 895:	learn: 0.0084359	total: 645ms	remaining: 74.8ms
# 896:	learn: 0.0083949	total: 645ms	remaining: 74.1ms
# 897:	learn: 0.0083466	total: 646ms	remaining: 73.4ms
# 898:	learn: 0.0082985	total: 647ms	remaining: 72.6ms
# 899:	learn: 0.0082582	total: 647ms	remaining: 71.9ms
# 900:	learn: 0.0082107	total: 648ms	remaining: 71.2ms
# 901:	learn: 0.0081707	total: 648ms	remaining: 70.4ms
# 902:	learn: 0.0081238	total: 649ms	remaining: 69.7ms
# 903:	learn: 0.0080771	total: 649ms	remaining: 69ms
# 904:	learn: 0.0080378	total: 650ms	remaining: 68.2ms
# 905:	learn: 0.0079917	total: 650ms	remaining: 67.5ms
# 906:	learn: 0.0079555	total: 651ms	remaining: 66.8ms
# 907:	learn: 0.0079098	total: 652ms	remaining: 66ms
# 908:	learn: 0.0078740	total: 652ms	remaining: 65.3ms
# 909:	learn: 0.0078288	total: 653ms	remaining: 64.6ms
# 910:	learn: 0.0077906	total: 653ms	remaining: 63.8ms
# 911:	learn: 0.0077526	total: 654ms	remaining: 63.1ms
# 912:	learn: 0.0077149	total: 655ms	remaining: 62.4ms
# 913:	learn: 0.0076706	total: 655ms	remaining: 61.6ms
# 914:	learn: 0.0076359	total: 656ms	remaining: 60.9ms
# 915:	learn: 0.0075921	total: 656ms	remaining: 60.2ms
# 916:	learn: 0.0075551	total: 657ms	remaining: 59.5ms
# 917:	learn: 0.0075183	total: 657ms	remaining: 58.7ms
# 918:	learn: 0.0074817	total: 658ms	remaining: 58ms
# 919:	learn: 0.0074387	total: 658ms	remaining: 57.3ms
# 920:	learn: 0.0074025	total: 659ms	remaining: 56.5ms
# 921:	learn: 0.0073600	total: 660ms	remaining: 55.8ms
# 922:	learn: 0.0073178	total: 660ms	remaining: 55.1ms
# 923:	learn: 0.0072847	total: 661ms	remaining: 54.3ms
# 924:	learn: 0.0072492	total: 661ms	remaining: 53.6ms
# 925:	learn: 0.0072139	total: 662ms	remaining: 52.9ms
# 926:	learn: 0.0071788	total: 662ms	remaining: 52.2ms
# 927:	learn: 0.0071376	total: 663ms	remaining: 51.4ms
# 928:	learn: 0.0070966	total: 664ms	remaining: 50.7ms
# 929:	learn: 0.0070645	total: 664ms	remaining: 50ms
# 930:	learn: 0.0070301	total: 665ms	remaining: 49.3ms
# 931:	learn: 0.0069897	total: 665ms	remaining: 48.5ms
# 932:	learn: 0.0069591	total: 666ms	remaining: 47.8ms
# 933:	learn: 0.0069276	total: 666ms	remaining: 47.1ms
# 934:	learn: 0.0068879	total: 667ms	remaining: 46.4ms
# 935:	learn: 0.0068567	total: 667ms	remaining: 45.6ms
# 936:	learn: 0.0068174	total: 668ms	remaining: 44.9ms
# 937:	learn: 0.0067842	total: 669ms	remaining: 44.2ms
# 938:	learn: 0.0067512	total: 669ms	remaining: 43.5ms
# 939:	learn: 0.0067184	total: 670ms	remaining: 42.7ms
# 940:	learn: 0.0066881	total: 670ms	remaining: 42ms
# 941:	learn: 0.0066556	total: 671ms	remaining: 41.3ms
# 942:	learn: 0.0066234	total: 671ms	remaining: 40.6ms
# 943:	learn: 0.0065911	total: 672ms	remaining: 39.9ms
# 944:	learn: 0.0065532	total: 672ms	remaining: 39.1ms
# 945:	learn: 0.0065155	total: 673ms	remaining: 38.4ms
# 946:	learn: 0.0064861	total: 674ms	remaining: 37.7ms
# 947:	learn: 0.0064488	total: 674ms	remaining: 37ms
# 948:	learn: 0.0064206	total: 675ms	remaining: 36.3ms
# 949:	learn: 0.0063916	total: 675ms	remaining: 35.5ms
# 950:	learn: 0.0063549	total: 676ms	remaining: 34.8ms
# 951:	learn: 0.0063271	total: 676ms	remaining: 34.1ms
# 952:	learn: 0.0062907	total: 677ms	remaining: 33.4ms
# 953:	learn: 0.0062623	total: 677ms	remaining: 32.7ms
# 954:	learn: 0.0062263	total: 678ms	remaining: 31.9ms
# 955:	learn: 0.0061983	total: 679ms	remaining: 31.2ms
# 956:	learn: 0.0061712	total: 679ms	remaining: 30.5ms
# 957:	learn: 0.0061357	total: 680ms	remaining: 29.8ms
# 958:	learn: 0.0061081	total: 680ms	remaining: 29.1ms
# 959:	learn: 0.0060730	total: 681ms	remaining: 28.4ms
# 960:	learn: 0.0060435	total: 681ms	remaining: 27.6ms
# 961:	learn: 0.0060163	total: 682ms	remaining: 26.9ms
# 962:	learn: 0.0059871	total: 682ms	remaining: 26.2ms
# 963:	learn: 0.0059527	total: 683ms	remaining: 25.5ms
# 964:	learn: 0.0059239	total: 684ms	remaining: 24.8ms
# 965:	learn: 0.0058972	total: 684ms	remaining: 24.1ms
# 966:	learn: 0.0058687	total: 685ms	remaining: 23.4ms
# 967:	learn: 0.0058404	total: 685ms	remaining: 22.7ms
# 968:	learn: 0.0058119	total: 686ms	remaining: 21.9ms
# 969:	learn: 0.0057784	total: 686ms	remaining: 21.2ms
# 970:	learn: 0.0057451	total: 687ms	remaining: 20.5ms
# 971:	learn: 0.0057193	total: 688ms	remaining: 19.8ms
# 972:	learn: 0.0056943	total: 688ms	remaining: 19.1ms
# 973:	learn: 0.0056615	total: 689ms	remaining: 18.4ms
# 974:	learn: 0.0056361	total: 689ms	remaining: 17.7ms
# 975:	learn: 0.0056036	total: 690ms	remaining: 17ms
# 976:	learn: 0.0055791	total: 690ms	remaining: 16.3ms
# 977:	learn: 0.0055470	total: 691ms	remaining: 15.5ms
# 978:	learn: 0.0055221	total: 691ms	remaining: 14.8ms
# 979:	learn: 0.0054903	total: 692ms	remaining: 14.1ms
# 980:	learn: 0.0054657	total: 693ms	remaining: 13.4ms
# 981:	learn: 0.0054418	total: 693ms	remaining: 12.7ms
# 982:	learn: 0.0054105	total: 694ms	remaining: 12ms
# 983:	learn: 0.0053862	total: 694ms	remaining: 11.3ms
# 984:	learn: 0.0053552	total: 695ms	remaining: 10.6ms
# 985:	learn: 0.0053293	total: 695ms	remaining: 9.87ms
# 986:	learn: 0.0053054	total: 696ms	remaining: 9.16ms
# 987:	learn: 0.0052749	total: 696ms	remaining: 8.46ms
# 988:	learn: 0.0052494	total: 697ms	remaining: 7.75ms
# 989:	learn: 0.0052241	total: 697ms	remaining: 7.04ms
# 990:	learn: 0.0052007	total: 698ms	remaining: 6.34ms
# 991:	learn: 0.0051756	total: 699ms	remaining: 5.63ms
# 992:	learn: 0.0051507	total: 699ms	remaining: 4.93ms
# 993:	learn: 0.0051255	total: 700ms	remaining: 4.22ms
# 994:	learn: 0.0050959	total: 700ms	remaining: 3.52ms
# 995:	learn: 0.0050665	total: 701ms	remaining: 2.81ms
# 996:	learn: 0.0050439	total: 702ms	remaining: 2.11ms
# 997:	learn: 0.0050148	total: 702ms	remaining: 1.41ms
# 998:	learn: 0.0049929	total: 703ms	remaining: 703us
# 999:	learn: 0.0049641	total: 703ms	remaining: 0us

# %% [markdown]
# Now that we trained a model we can gat the shap values for each fingerprint bit.

# %%
##################################################
##calculate the shap values
##################################################

explainer = shap.TreeExplainer(model)
shap_vals = explainer.shap_values(featuresMorganCounts)

# %% [markdown]
# As we now have the shap values we can use them to calculate a distance matrix based on spearman correlation. Use the distance to for UMAP and store the emebdding vectors in the sdfExportData

# %%
#######################################################################
## Calculate umap based on the shap values and add to the data frame ##
#######################################################################

#We use spearman correlation as a proximity measure, scale it to a range
#between 0 and 1 and transform it to a distance to be used in umap
umap_dist = 1 - (pd.DataFrame(shap_vals).T.corr(method="spearman") + 1) / 2

my_umap = umap.UMAP(metric='precomputed')

my_umap_fit = my_umap.fit_transform(umap_dist)

print("Finished UMAP")

#get the coordinates
x = my_umap_fit[:, 0]
y = my_umap_fit[:, 1]

#add the coordinates to the data object
sdfExportData["x"] = x
sdfExportData["y"] = y
# Out:
# using precomputed metric; inverse_transform will be unavailable
# n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
# Finished UMAP

# %% [markdown]
# Now lets add some dummy groupLabels

# %%
groups = np.zeros((len(sdfExportData),))
groups[3:] = 1
sdfExportData["groupLabel"] = groups

# %% [markdown]
# Now lets use the shap values to assign atom attributions based on the model for logp prediction

# %%
####################################################
#now assign weights based on the model
###################################################

#first we have to calculate the atom indices associated with each fingerprint bit
indices =  [calc_indices_for_fingerprints(smi,radius = 2,nBits=2048) for smi in smiles]

#we also store the column names of the fingerprint matrix
featureNames = featuresMorganCounts.columns

#set direction to "up" if you only want the positive attributions
#to "down" for only the positive attributions and "both" summing up over positive and
#negative attributions
modelAttributions = [list(atom_attributions(mols[i], indices[i], shap_vals[i],featureNames , direction="both")) for i in range(len(smiles))]

####################################################################################
##Add the modelAttributions to the logp as one string for each compound
####################################################################################

sdfExportData["atom.Contribution.rep_modelAttributions"] = [' '.join([str(round(i, 4)) for i in modelAttributions[j]]) for
                                                           j in range(len(modelAttributions))]

# %% [markdown]
# To compare the model attribution against them we also calculate the crippen contributions

# %%
######################################################
##Calculate the Crippen Contribs to the logp values
######################################################

logp_contribs = [[x for x, y in rdMolDescriptors._CalcCrippenContribs(mols[i])] for i in range(len(mols))]

sdfExportData["atom.Contribution.rep_CrippenContribs"] = [' '.join([str(round(i, 4)) for i in logp_contribs[j]]) for j
                                                          in range(len(logp_contribs))]

# %% [markdown]
# As both attributions (Crippen and Model) were stored in the sdfExportData we prepare the data frame fro export to sdf

# %%
#######################################################################################
#add the chemical info to the data frame
#######################################################################################
# smilesCol: in which column the smiles are located
PandasTools.AddMoleculeColumnToFrame(sdfExportData, smilesCol='smiles', molCol='ROMol', includeFingerprints=False)
# to avoid duplicate smiles column
del sdfExportData['smiles']

# %% [markdown]
# Now we can write the data frame as an sdf file for use in CIME

# %%
########################################################################
###Export as an sdf file you can read into CIME
########################################################################

PandasTools.WriteSDF(sdfExportData,"SDF_OUTPUT.sdf",
                     properties=list(sdfExportData.columns), idName="RowID")
